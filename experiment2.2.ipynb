# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyankargouri/ANN/blob/main/experiment2.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def compute_cost(x, y, m, b):
    n = len(y)
    predictions = m * x + b
    cost = (1 / (2 * n)) * np.sum((predictions - y) ** 2)
    return cost

def gradient_descent(x, y, m, b, learning_rate, iterations):
    n = len(y)
    for _ in range(iterations):
        predictions = m * x + b
        dm = (-2 / n) * np.sum(x * (y - predictions))
        db = (-2 / n) * np.sum(y - predictions)
        m -= learning_rate * dm
        b -= learning_rate * db
    return m, b

# Sample dataset: Altitude vs Temperature
x = np.array([500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000])  # Altitude (meters)
y = np.array([25, 22, 18, 15, 12, 10, 7, 5, 2, 0])  # Temperature (Celsius)

# Initial values
m = 0
b = 0
learning_rate = 0.0001
iterations = 1000

# Train model using Gradient Descent
m, b = gradient_descent(x, y, m, b, learning_rate, iterations)

# Predictions
y_pred = m * x + b

# Display results
print(f"Best-fit line: y = {m:.5f}x + {b:.2f}")

# Plot data and regression line
plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, y_pred, color='red', label='Best-fit Line')
plt.xlabel("Altitude (meters)")
plt.ylabel("Temperature (Celsius)")
plt.title("Temperature Prediction Based on Altitude")
plt.legend()
plt.grid()
plt.show()
# Out:
# <ipython-input-1-701ec33d5875>:14: RuntimeWarning: overflow encountered in multiply
#   dm = (-2 / n) * np.sum(x * (y - predictions))
# <ipython-input-1-701ec33d5875>:16: RuntimeWarning: invalid value encountered in scalar subtract
#   m -= learning_rate * dm
# Best-fit line: y = nanx + nan
